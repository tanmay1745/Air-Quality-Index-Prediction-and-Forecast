# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Preprocessed_Data_Final.xls")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1449833 entries, 0 to 1449832
# Data columns (total 50 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   Unnamed: 0                 1449833 non-null  int64
#  1   StationId                  1449833 non-null  object
#  2   StationId_enc              1449833 non-null  int64
#  3   PM2.5                      1449833 non-null  float64
#  4   NO2                        1449833 non-null  float64
#  5   CO                         1449833 non-null  float64
#  6   SO2                        1449833 non-null  float64
#  7   O3                         1449833 non-null  float64
#  8   AQI                        1449833 non-null  float64
#  9   Temperature                1449833 non-null  float64
#  10  DewPoint                   1449833 non-null  float64
#  11  WindDirection              1449833 non-null  float64
#  12  WindSpeed                  1449833 non-null  float64
#  13  Pressure                   1449833 non-null  float64
#  14  RelativeHumidity           1449833 non-null  float64
#  15  PM25_lag1                  1449833 non-null  float64
#  16  PM25_lag3                  1449833 non-null  float64
#  17  PM25_lag6                  1449833 non-null  float64
#  18  PM25_lag24                 1449833 non-null  float64
#  19  NO2_lag1                   1449833 non-null  float64
#  20  O3_lag1                    1449833 non-null  float64
#  21  PM25_roll3                 1449833 non-null  float64
#  22  PM25_roll6                 1449833 non-null  float64
#  23  PM25_roll12                1449833 non-null  float64
#  24  PM25_roll24                1449833 non-null  float64
#  25  Hour_sin                   1449833 non-null  float64
#  26  Hour_cos                   1449833 non-null  float64
#  27  Month_sin                  1449833 non-null  float64
#  28  Month_cos                  1449833 non-null  float64
#  29  Pollution_Load             1449833 non-null  float64
#  30  PM_Ratio                   1449833 non-null  float64
#  31  Temp_Humidity_Interaction  1449833 non-null  float64
#  32  Wind_Inv                   1449833 non-null  float64
#  33  Datetime                   1449833 non-null  object
#  34  Hour                       1449833 non-null  int64
#  35  DayOfWeek                  1449833 non-null  int64
#  36  IsWeekend                  1449833 non-null  int64
#  37  Month                      1449833 non-null  int64
#  38  Quarter                    1449833 non-null  int64
#  39  DayOfYear                  1449833 non-null  int64
#  40  Year                       1449833 non-null  int64
#  41  Day_Monday                 1449833 non-null  int64
#  42  Day_Saturday               1449833 non-null  int64
#  43  Day_Sunday                 1449833 non-null  int64
#  44  Day_Thursday               1449833 non-null  int64
#  45  Day_Tuesday                1449833 non-null  int64
#  46  Day_Wednesday              1449833 non-null  int64
#  47  Season_PostMonsoon         1449833 non-null  int64
#  48  Season_Summer              1449833 non-null  int64
#  49  Season_Winter              1449833 non-null  int64
# dtypes: float64(30), int64(18), object(2)
# memory usage: 553.1+ MB

# %%
import pickle
with open("feature_cols_new.pkl", "rb") as f:
    fl = pickle.load(f)

# %%
stations = pd.read_csv("Final_Station.csv")

# %%
stations
# Out:
#     Unnamed: 0 StationId        StationName         City  Latitude  Longitude  \
# 0            0     AP001          Gollapudi   Vijayawada   16.5211    80.6482
# 1            1     AP005           Tirumala     Tirupati   13.6837    79.3473
# 2            2     AS001       Bamunimaidan     Guwahati   26.1849    91.7926
# 3            3     BR007            Danapur        Patna   25.6124    85.0472
# 4            4     BR008           Shivpuri        Patna   25.6198    85.1586
# ..         ...       ...                ...          ...       ...        ...
# 91          91     WB009  Victoria Memorial      Kolkata   22.5445    88.3420
# 92          92     WB010         Ballygunge      Kolkata   22.5239    88.3673
# 93          93     WB011           Jadavpur      Kolkata   22.4974    88.3717
# 94          94     WB012        Barrackpore  Barrackpore   22.7638    88.3631
# 95          95     WB013             Howrah       Howrah   22.5958    88.3156
#
#     StationId_enc  waqi_id                    waqi_city_name
# 0             0.0    11280     Secretariat, Amaravati, India
# 1             1.0     9069   Tirumala-APPCB, Tirupati, India
# 2             2.0    11844   Railway Colony, Guwahati, India
# 3             3.0    12888  DRM Office Danapur, Patna, India
# 4             4.0    12744            Muradpur, Patna, India
# ..            ...      ...                               ...
# 91           91.0     9068          Victoria, Kolkata, India
# 92           92.0    12746        Ballygunge, Kolkata, India
# 93           93.0    12458          Jadavpur, Kolkata, India
# 94           94.0    12450         Belur Math, Howrah, India
# 95           95.0    11281            Ghusuri, Howrah, India
#
# [96 rows x 9 columns]

# %% [markdown]
# # aqi_system.py
# Combined pipeline for:
#   - Current AQI (nowcast) for all stations
#   - 24-hour hourly forecast (recursive autoregressive)
#   - Save hourly history for every station (data/hourly_history.csv)
#   - Save per-station 24h forecast CSVs under forecast/

# %%
import os
import json
import time
from datetime import datetime, timedelta
import requests
import joblib

# %%
# CONFIG
API_KEY = "YOUR_API_KEY_HERE"

BASE = r"C:/Users/vijay/Documents/Tanmay/AQI"  

STATIONS_PATH = rf"{BASE}/Final_Station.csv"
MODEL_PATH = rf"{BASE}/models/CatBoost_Optimized.pkl"
FEATURE_PATH = rf"{BASE}/models/feature_cols_new.pkl"
HISTORICAL_UPLOAD_PATH = rf"{BASE}/data/Preprocessed_Data_Final.xls"

HISTORY_FILE = rf"{BASE}/hourly_history.csv"
FORECAST_DIR = rf"{BASE}/forecast"   # will be created automatically

SLEEP_BETWEEN = 0.5

os.makedirs(FORECAST_DIR, exist_ok=True)

# %%
# Helpers 
def load_stations(path=STATIONS_PATH):
    if not os.path.exists(path):
        raise FileNotFoundError(f"Stations file not found: {path}")
    df = pd.read_csv(path)
    required = {"StationId", "StationName", "City", "waqi_id", "StationId_enc"}
    missing = required - set(df.columns)
    if missing:
        raise ValueError(f"Stations CSV missing columns: {missing}")
    return df

# %%
def fetch_live_waqi(waqi_id):
    """
    Fetch WAQI feed for a station and return a normalized live dict.
    This will try to extract all commonly available iaqi fields and map them to the
    feature names your model expects:
      - PM2.5, NO2, CO, SO2, O3
      - Temperature, RelativeHumidity, WindSpeed
      - Pressure (p), DewPoint (dew), WindDirection (wd)
    Missing values -> 0 (you can change fallback to np.nan if preferred).
    Returns (live_dict, status_str)
    """
    url = f"https://api.waqi.info/feed/@{waqi_id}/?token={API_KEY}"
    try:
        r = requests.get(url, timeout=10)
        r.raise_for_status()
        data = r.json()
    except Exception as e:
        return None, f"error: {e}"

    if data.get("status") != "ok":
        return None, f"waqi_status_{data.get('status')}"

    iaqi = data["data"].get("iaqi", {}) or {}

    # helper to safely get nested numeric v value (and coerce to float)
    def g(key):
        try:
            v = iaqi.get(key, {})
            return float(v.get("v")) if isinstance(v, dict) and "v" in v else float(v) if isinstance(v, (int, float)) else 0.0
        except Exception:
            return 0.0

    # WAQI sometimes uses slightly different keys; check common variants
    # Primary keys we expect: 'pm25','no2','co','so2','o3','t','h','w','p','dew','wd'
    live = {
        "PM2.5": g("pm25"),
        "NO2": g("no2"),
        "CO": g("co"),
        "SO2": g("so2"),
        "O3": g("o3"),
        "Temperature": g("t"),            # WAQI 't' is temp
        "RelativeHumidity": g("h"),       # WAQI 'h' is humidity
        "WindSpeed": g("w"),              # WAQI 'w' is wind speed
        # additional fields (map to your feature_list names)
        "Pressure": g("p") or g("pressure"),
        "DewPoint": g("dew") or g("dewpoint"),
        "WindDirection": g("wd") or g("winddir") or g("wind_direction"),
    }

    # Some feeds embed values under different keys (rare) — attempt a second pass
    # if any of the additional keys are zero, try scanning iaqi keys for close matches.
    if live["Pressure"] == 0.0 or live["DewPoint"] == 0.0 or live["WindDirection"] == 0.0:
        for k, v in iaqi.items():
            if not isinstance(v, dict):
                continue
            key_lower = k.lower()
            val = v.get("v", None)
            if val is None:
                continue
            try:
                val = float(val)
            except Exception:
                continue
            if live["Pressure"] == 0.0 and ("p" in key_lower or "press" in key_lower):
                live["Pressure"] = val
            if live["DewPoint"] == 0.0 and ("dew" in key_lower):
                live["DewPoint"] = val
            if live["WindDirection"] == 0.0 and ("wd" in key_lower or "dir" in key_lower):
                live["WindDirection"] = val

    return live, "ok"

# %%
def ensure_feature_list(features_path=FEATURE_PATH, fallback_hist=HISTORICAL_UPLOAD_PATH):
    """
    Ensure JSON feature list exists. If not, try to build from historical file columns.
    Feature list = all columns in historical df minus ["AQI","StationId","Datetime","Unnamed: 0"].
    """
    if os.path.exists(features_path):
        feature_list = joblib.load(FEATURE_PATH)
        return feature_list

    # Try to build from historical upload
    if os.path.exists(fallback_hist):
        print("nowcast feature JSON not found — building from historical file:", fallback_hist)
        try:
            hist = pd.read_csv(fallback_hist)
        except Exception:
            hist = pd.read_excel(fallback_hist)
        cols = [c for c in hist.columns if c not in ["AQI", "StationId", "Datetime", "Unnamed: 0"]]
        # keep only numeric/time/encoded features (exclude object columns if any)
        numeric_cols = [c for c in cols if hist[c].dtype in [np.float64, np.int64, np.int32, np.float32]]
        # but also keep engineered time columns if present
        # final list: numeric_cols + any known time/one-hot columns that exist
        extras = [c for c in cols if c not in numeric_cols]
        features = numeric_cols + extras
        with open(features_path, "w") as f:
            json.dump(features, f)
        print(f"Feature JSON created at {features_path} with {len(features)} features.")
        return features

    raise FileNotFoundError(
        f"Feature JSON not found ({features_path}) and historical file not available ({fallback_hist})"
    )

# %%
def build_feature_row(live_dict, station_enc, feature_list, dt=None, history_path=HISTORY_FILE):
    """
    Build a single-row feature DataFrame matching feature_list.
    Includes:
      - Raw WAQI pollutants/weather (PM2.5, NO2, CO, SO2, O3, Temp, RH, WindSpeed, Pressure, DewPoint, WindDirection)
      - Time features (Hour_sin, Hour_cos, Month_sin, Month_cos, DOW one-hot, Season one-hot)
      - Engineered features (Pollution_Load, PM_Ratio, Temp*Humidity, Wind_Inv)
      - Lags: PM25_lag1, lag3, lag6, lag24; NO2_lag1, O3_lag1
      - Rolling means: roll3, roll6, roll12, roll24
    """
    import pandas as pd
    import numpy as np
    from datetime import datetime

    if dt is None:
        dt = datetime.now()

    # Base row 
    row = pd.DataFrame([[0] * len(feature_list)], columns=feature_list)

    # Fill direct live features 
    for col, val in live_dict.items():
        if col in row.columns:
            row[col] = float(val)

    # Load station history (needed for lags/rollings)
    try:
        hist = pd.read_csv(history_path)
        hist["Datetime"] = pd.to_datetime(hist["Datetime"])
        hist = hist[hist["StationId_enc"] == station_enc] if "StationId_enc" in hist.columns else hist
        hist = hist.sort_values("Datetime")
    except:
        hist = pd.DataFrame()

    # Helper to get latest value of a column
    def get_latest(col):
        try:
            return float(hist[col].iloc[-1])
        except:
            return float(live_dict.get(col, 0))

    # PM2.5 Lag Features 
    def get_lag(series, lag_hours):
        try:
            return float(series.iloc[-lag_hours])
        except:
            return float(get_latest("PM2.5"))

    if not hist.empty and "PM2.5" in hist.columns:
        pm25_series = hist["PM2.5"]

        # PM25 Lags
        if "PM25_lag1" in row.columns:
            row["PM25_lag1"] = get_lag(pm25_series, 1)
        if "PM25_lag3" in row.columns:
            row["PM25_lag3"] = get_lag(pm25_series, 3)
        if "PM25_lag6" in row.columns:
            row["PM25_lag6"] = get_lag(pm25_series, 6)
        if "PM25_lag24" in row.columns:
            row["PM25_lag24"] = get_lag(pm25_series, 24)

        # Rolling means
        def roll(series, w):
            if len(series) >= w:
                return float(series.tail(w).mean())
            else:
                return float(series.mean())

        if "PM25_roll3" in row.columns:
            row["PM25_roll3"] = roll(pm25_series, 3)
        if "PM25_roll6" in row.columns:
            row["PM25_roll6"] = roll(pm25_series, 6)
        if "PM25_roll12" in row.columns:
            row["PM25_roll12"] = roll(pm25_series, 12)
        if "PM25_roll24" in row.columns:
            row["PM25_roll24"] = roll(pm25_series, 24)

    # NO2 & O3 Lag 1 
    if not hist.empty:
        if "NO2_lag1" in row.columns:
            try:
                row["NO2_lag1"] = float(hist["NO2"].iloc[-1])
            except:
                row["NO2_lag1"] = float(live_dict.get("NO2", 0))

        if "O3_lag1" in row.columns:
            try:
                row["O3_lag1"] = float(hist["O3"].iloc[-1])
            except:
                row["O3_lag1"] = float(live_dict.get("O3", 0))

    # Time based features 
    # Cyclic hour and month
    if "Hour_sin" in row.columns:
        row["Hour_sin"] = np.sin(2 * np.pi * dt.hour / 24)
    if "Hour_cos" in row.columns:
        row["Hour_cos"] = np.cos(2 * np.pi * dt.hour / 24)
    if "Month_sin" in row.columns:
        row["Month_sin"] = np.sin(2 * np.pi * dt.month / 12)
    if "Month_cos" in row.columns:
        row["Month_cos"] = np.cos(2 * np.pi * dt.month / 12)

    # Hour, DayOfWeek, Month, Quarter, Year, DayOfYear, IsWeekend
    if "Hour" in row.columns: row["Hour"] = dt.hour
    if "DayOfWeek" in row.columns: row["DayOfWeek"] = dt.weekday()
    if "IsWeekend" in row.columns: row["IsWeekend"] = int(dt.weekday() >= 5)
    if "Month" in row.columns: row["Month"] = dt.month
    if "Quarter" in row.columns: row["Quarter"] = (dt.month - 1) // 3 + 1
    if "DayOfYear" in row.columns: row["DayOfYear"] = dt.timetuple().tm_yday
    if "Year" in row.columns: row["Year"] = dt.year

    # Day-of-week one-hot
    dow = dt.weekday()
    dow_map = ["Day_Monday", "Day_Tuesday", "Day_Wednesday", "Day_Thursday",
               "Day_Friday", "Day_Saturday", "Day_Sunday"]
    for i, c in enumerate(dow_map):
        if c in row.columns: row[c] = 1 if i == dow else 0

    # Season one-hot
    if "Season_Winter" in row.columns:
        row["Season_Winter"] = 1 if dt.month in [12, 1, 2] else 0
    if "Season_Summer" in row.columns:
        row["Season_Summer"] = 1 if dt.month in [4, 5, 6] else 0
    if "Season_PostMonsoon" in row.columns:
        row["Season_PostMonsoon"] = 1 if dt.month in [10, 11] else 0

    # Engineered interactions
    pm25 = float(live_dict.get("PM2.5", 0))
    no2 = float(live_dict.get("NO2", 0))
    o3 = float(live_dict.get("O3", 0))
    temp = float(live_dict.get("Temperature", 0))
    rh = float(live_dict.get("RelativeHumidity", 0))
    ws = float(live_dict.get("WindSpeed", 0))

    if "Pollution_Load" in row.columns:
        row["Pollution_Load"] = pm25 + no2 + live_dict.get("CO", 0) + live_dict.get("SO2", 0) + o3

    if "PM_Ratio" in row.columns:
        row["PM_Ratio"] = pm25 / (no2 + o3 + 1e-6)

    if "Temp_Humidity_Interaction" in row.columns:
        row["Temp_Humidity_Interaction"] = temp * rh

    if "Wind_Inv" in row.columns:
        row["Wind_Inv"] = 1.0 / (ws + 1e-6)

    # Station Encoding 
    if "StationId_enc" in row.columns:
        row["StationId_enc"] = station_enc

    return row

# %%
def save_hourly_history(entry, history_path=HISTORY_FILE):
    """
    Append a new hourly entry to history CSV.
    Ensures:
      - Consistent columns
      - New columns auto-added if needed
      - Sorted by datetime
      - No duplicate timestamps per station
    """
    import pandas as pd
    import numpy as np
    import os

    df_entry = pd.DataFrame([entry])

    # If file does not exist → create it with this row
    if not os.path.exists(history_path):
        df_entry.to_csv(history_path, index=False)
        return

    # Load existing history
    try:
        hist = pd.read_csv(history_path)
    except Exception:
        hist = pd.DataFrame()

    # Ensure Datetime is datetime
    try:
        df_entry["Datetime"] = pd.to_datetime(df_entry["Datetime"])
        if "Datetime" in hist.columns:
            hist["Datetime"] = pd.to_datetime(hist["Datetime"])
    except:
        pass

    # Ensure all columns exist in both 
    all_cols = sorted(list(set(hist.columns).union(set(df_entry.columns))))

    for col in all_cols:
        if col not in hist.columns:
            hist[col] = np.nan
        if col not in df_entry.columns:
            df_entry[col] = np.nan

    hist = hist[all_cols]
    df_entry = df_entry[all_cols]

    # Remove duplicates for SAME station + datetime 
    if "StationId" in all_cols and "Datetime" in all_cols:
        before_len = len(hist)
        hist = hist[~(
            (hist["StationId"] == df_entry["StationId"].iloc[0]) &
            (hist["Datetime"] == df_entry["Datetime"].iloc[0])
        )]
        # (optional) print(f"Removed duplicates: {before_len-len(hist)}")

    # Append new entry 
    hist = pd.concat([hist, df_entry], ignore_index=True)

    # Sort by datetime (important for lags/rolling) 
    if "Datetime" in hist.columns:
        hist = hist.sort_values("Datetime")

    # Save 
    hist.to_csv(history_path, index=False)

# %%
def forecast_24h_recursive(aqi_now, live_dict, model, feature_list, station_enc=0, seed_dt=None):
    """
    24-hour forecast using static live pollutant/weather features.
    Why static?
      - Your model uses PM2.5 lag/rolling from HISTORY, NOT future predictions.
      - For forecasting, WAQI future values are unknown.
    So:
      - We only vary datetime-dependent features (hour, DOW, month, season, etc.)
      - Pollutants/weather remain last-known values (live_dict)
      - Lags/rollings remain based on HISTORY (computed inside build_feature_row)
    """
    from datetime import datetime, timedelta
    import pandas as pd

    if seed_dt is None:
        seed_dt = datetime.now()

    out = []

    for h in range(1, 25):
        forecast_dt = seed_dt + timedelta(hours=h)

        # Build feature row for this future hour
        row = build_feature_row(
            live_dict=live_dict,
            station_enc=station_enc,
            feature_list=feature_list,
            dt=forecast_dt
        )

        # Predict
        try:
            pred = float(model.predict(row)[0])
        except Exception as e:
            pred = float("nan")

        out.append({"Datetime": forecast_dt, "AQI": pred})

    return pd.DataFrame(out)

# %%
# Main pipeline 
def run_pipeline():
    import pandas as pd
    import numpy as np
    from datetime import datetime
    import os
    import time

    # 1) Load stations
    stations = load_stations(STATIONS_PATH)

    # 2) Load feature list (47 features)
    features = ensure_feature_list(FEATURE_PATH, HISTORICAL_UPLOAD_PATH)

    # 3) Load model
    if not os.path.exists(MODEL_PATH):
        raise FileNotFoundError(f"Model not found at: {MODEL_PATH}")
    model = joblib.load(MODEL_PATH)

    all_now = []

    # 4) Iterate through each station
    for idx, s in stations.iterrows():
        st_id = s["StationId"]
        waqi_id = s["waqi_id"]
        st_enc = s["StationId_enc"]

        # Fetch live WAQI data 
        live, status = fetch_live_waqi(waqi_id)
        if live is None:
            print(f"[{st_id}] WAQI fetch failed: {status}")
            time.sleep(SLEEP_BETWEEN)
            continue

        # Build feature row for NOW 
        row = build_feature_row(
            live_dict=live,
            station_enc=st_enc,
            feature_list=features,
            dt=datetime.now()
        )

        # Predict current AQI
        try:
            aqi_now = float(model.predict(row)[0])
        except Exception as e:
            print(f"[{st_id}] Model prediction failed: {e}")
            time.sleep(SLEEP_BETWEEN)
            continue

        # Save hourly history entry 
        hist_entry = {
            "StationId": st_id,
            "StationName": s.get("StationName", ""),
            "City": s.get("City", ""),
            "StationId_enc": st_enc,
            "Datetime": datetime.now().isoformat(),

            # model target
            "AQI": aqi_now,

            # pollutants
            "PM2.5": live.get("PM2.5"),
            "NO2": live.get("NO2"),
            "CO": live.get("CO"),
            "SO2": live.get("SO2"),
            "O3": live.get("O3"),

            # weather
            "Temperature": live.get("Temperature"),
            "RelativeHumidity": live.get("RelativeHumidity"),
            "WindSpeed": live.get("WindSpeed"),
            "Pressure": live.get("Pressure"),
            "DewPoint": live.get("DewPoint"),
            "WindDirection": live.get("WindDirection")
        }

        save_hourly_history(hist_entry, HISTORY_FILE)

        # 24-hour forecast 
        forecast_df = forecast_24h_recursive(
            aqi_now=aqi_now,
            live_dict=live,
            model=model,
            feature_list=features,
            station_enc=st_enc,
            seed_dt=datetime.now()
        )

        # Save forecast output
        out_csv = os.path.join(FORECAST_DIR, f"forecast_24h_{st_id}.csv")
        forecast_df.to_csv(out_csv, index=False)
        print(f"[{st_id}] AQI Now: {aqi_now:.1f} | Forecast saved → {out_csv}")

        # Add to nowcast snapshot list
        all_now.append({
            "StationId": st_id,
            "StationName": s.get("StationName", ""),
            "City": s.get("City", ""),
            "AQI_Now": aqi_now,
            "Datetime": datetime.now().isoformat()
        })

        time.sleep(SLEEP_BETWEEN)

    # Save snapshot of all predictions 
    if all_now:
        df_now = pd.DataFrame(all_now)
        snap_dir = os.path.join(BASE, "nowcast_snapshot")
        os.makedirs(snap_dir, exist_ok=True)

        snapshot_path = os.path.join(
            snap_dir,
            f"nowcast_snapshot_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"
        )
        df_now.to_csv(snapshot_path, index=False)
        print("Snapshot saved →", snapshot_path)


if __name__ == "__main__":
    print("Starting AQI pipeline: Live Nowcast + 24h Forecast")
    run_pipeline()
    print("Pipeline complete. History updated at:", HISTORY_FILE)
# Out:
# Starting AQI pipeline: Live Nowcast + 24h Forecast
# C:\Users\HRUDANSH\AppData\Local\Temp\ipykernel_7232\3878468437.py:57: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   hist = pd.concat([hist, df_entry], ignore_index=True)
# [AP001] AQI Now: 105.8 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_AP001.csv
# [AP005] AQI Now: 164.7 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_AP005.csv
# [AS001] AQI Now: 167.0 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_AS001.csv
# [BR007] AQI Now: 246.2 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_BR007.csv
# [BR008] AQI Now: 241.2 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_BR008.csv
# [BR009] AQI Now: 261.3 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_BR009.csv
# [BR010] AQI Now: 104.2 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_BR010.csv
# [DL001] AQI Now: 170.1 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_DL001.csv
# [DL002] AQI Now: 237.5 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_DL002.csv
# [DL003] AQI Now: 294.3 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_DL003.csv
# [DL004] AQI Now: 262.3 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_DL004.csv
# [DL005] AQI Now: 312.3 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_DL005.csv
# [DL006] AQI Now: 106.1 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_DL006.csv
# [DL007] AQI Now: 313.4 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_DL007.csv
# [DL008] AQI Now: 99.2 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_DL008.csv
# [DL009] AQI Now: 103.9 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_DL009.csv
# [DL010] AQI Now: 377.5 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_DL010.csv
# [DL012] AQI Now: 102.2 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_DL012.csv
# [DL013] AQI Now: 189.8 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_DL013.csv
# [DL014] AQI Now: 431.7 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_DL014.csv
# [DL015] AQI Now: 322.4 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_DL015.csv
# [DL016] AQI Now: 265.8 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_DL016.csv
# [DL017] AQI Now: 104.4 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_DL017.csv
# [DL018] AQI Now: 339.6 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_DL018.csv
# [DL019] AQI Now: 440.1 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_DL019.csv
# [DL020] AQI Now: 308.1 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_DL020.csv
# [DL021] AQI Now: 279.9 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_DL021.csv
# [DL022] AQI Now: 305.4 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_DL022.csv
# [DL023] AQI Now: 112.3 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_DL023.csv
# [DL024] AQI Now: 309.5 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_DL024.csv
# [DL025] AQI Now: 317.6 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_DL025.csv
# [DL026] AQI Now: 347.2 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_DL026.csv
# [DL027] AQI Now: 192.7 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_DL027.csv
# [DL028] AQI Now: 236.7 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_DL028.csv
# [DL029] AQI Now: 311.2 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_DL029.csv
# [DL030] AQI Now: 171.6 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_DL030.csv
# [DL031] AQI Now: 374.8 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_DL031.csv
# [DL032] AQI Now: 278.1 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_DL032.csv
# [DL033] AQI Now: 230.5 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_DL033.csv
# [DL034] AQI Now: 274.0 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_DL034.csv
# [DL035] AQI Now: 263.5 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_DL035.csv
# [DL036] AQI Now: 94.0 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_DL036.csv
# [DL037] AQI Now: 265.9 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_DL037.csv
# [DL038] AQI Now: 375.2 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_DL038.csv
# [GJ001] AQI Now: 257.5 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_GJ001.csv
# [HR011] AQI Now: 174.5 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_HR011.csv
# [HR014] AQI Now: 412.2 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_HR014.csv
# [KA002] AQI Now: 263.7 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_KA002.csv
# [KA003] AQI Now: 195.2 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_KA003.csv
# [KA004] AQI Now: 325.4 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_KA004.csv
# [KA005] AQI Now: 78.7 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_KA005.csv
# [KA006] AQI Now: 60.9 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_KA006.csv
# [KA007] AQI Now: 265.2 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_KA007.csv
# [KA008] AQI Now: 110.9 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_KA008.csv
# [KA009] AQI Now: 114.4 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_KA009.csv
# [KA010] AQI Now: 323.8 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_KA010.csv
# [KA011] AQI Now: 62.8 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_KA011.csv
# [MH005] AQI Now: 65.7 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_MH005.csv
# [MH006] AQI Now: 83.4 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_MH006.csv
# [MH007] AQI Now: 83.4 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_MH007.csv
# [MH008] AQI Now: 169.0 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_MH008.csv
# [MH009] AQI Now: 273.6 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_MH009.csv
# [MH010] AQI Now: 467.3 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_MH010.csv
# [MH011] AQI Now: 183.1 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_MH011.csv
# [MH012] AQI Now: 235.4 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_MH012.csv
# [MH013] AQI Now: 296.2 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_MH013.csv
# [MH014] AQI Now: 235.1 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_MH014.csv
# [MP001] AQI Now: 203.2 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_MP001.csv
# [OD001] AQI Now: 239.9 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_OD001.csv
# [PB001] AQI Now: 307.6 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_PB001.csv
# [RJ004] AQI Now: 168.0 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_RJ004.csv
# [RJ005] AQI Now: 95.8 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_RJ005.csv
# [RJ006] AQI Now: 253.4 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_RJ006.csv
# [TG001] AQI Now: 181.9 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_TG001.csv
# [TG002] AQI Now: 100.9 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_TG002.csv
# [TG003] AQI Now: 104.3 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_TG003.csv
# [TG004] AQI Now: 101.1 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_TG004.csv
# [TG005] AQI Now: 330.8 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_TG005.csv
# [TG006] AQI Now: 127.3 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_TG006.csv
# [TN001] AQI Now: 193.1 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_TN001.csv
# [TN002] AQI Now: 216.7 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_TN002.csv
# [TN003] AQI Now: 100.5 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_TN003.csv
# [TN004] AQI Now: 83.2 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_TN004.csv
# [TN005] AQI Now: 66.2 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_TN005.csv
# [UP012] AQI Now: 195.3 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_UP012.csv
# [UP013] AQI Now: 113.6 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_UP013.csv
# [UP014] AQI Now: 252.0 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_UP014.csv
# [UP015] AQI Now: 176.6 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_UP015.csv
# [UP016] AQI Now: 129.6 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_UP016.csv
# [WB007] AQI Now: 284.9 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_WB007.csv
# [WB008] AQI Now: 207.8 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_WB008.csv
# [WB009] AQI Now: 148.4 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_WB009.csv
# [WB010] AQI Now: 208.4 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_WB010.csv
# [WB011] AQI Now: 156.4 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_WB011.csv
# [WB012] AQI Now: 193.2 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_WB012.csv
# [WB013] AQI Now: 115.9 | Forecast saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/forecast\forecast_24h_WB013.csv
# Snapshot saved → C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI\nowcast_snapshot\nowcast_snapshot_20251124_175036.csv
# Pipeline complete. History updated at: C:\Users\HRUDANSH\Documents\Tanmay Bari\Alll_about_AQI/hourly_history.csv

# %% [markdown]
# # View Results

# %%
import pandas as pd
df_history = pd.read_csv("hourly_history.csv")
df_history.sort_values("Datetime")
# Out:
#            AQI   CO         City                    Datetime  DewPoint   NO2  \
# 0   105.792849  3.8   Vijayawada  2025-11-24 17:47:55.098270      22.0   9.6
# 1   164.683976  5.7     Tirupati  2025-11-24 17:47:56.836057      24.0   5.7
# 2   166.995939  6.3     Guwahati  2025-11-24 17:47:58.510199      20.0   1.2
# 3   246.227440  8.7        Patna  2025-11-24 17:48:00.114073       9.0  39.6
# 4   241.174240  9.1        Patna  2025-11-24 17:48:01.866823       9.0   4.0
# ..         ...  ...          ...                         ...       ...   ...
# 91  148.399398  4.8      Kolkata  2025-11-24 17:50:28.504600      13.0   7.0
# 92  208.376393  6.8      Kolkata  2025-11-24 17:50:30.279598      13.0  16.6
# 93  156.438305  4.7      Kolkata  2025-11-24 17:50:31.879005      13.0  25.1
# 94  193.192911  6.5  Barrackpore  2025-11-24 17:50:33.428010      13.0  13.8
# 95  115.917624  3.2       Howrah  2025-11-24 17:50:35.031332      13.0   9.1
#
#       O3  PM2.5     Pressure  RelativeHumidity   SO2 StationId  StationId_enc  \
# 0   16.9   94.0   759.000000         62.000000   2.3     AP001            0.0
# 1    2.5  109.0   686.000000         89.000000   2.6     AP005            1.0
# 2    0.0   80.0  1100.000000         68.080000  13.0     AS001            2.0
# 3   12.4  151.0   757.090000         65.490000   3.5     BR007            3.0
# 4   15.9  155.0   756.733333         44.533333   3.6     BR008            4.0
# ..   ...    ...          ...               ...   ...       ...            ...
# 91  20.5  182.0  1011.200000         68.570000   2.4     WB009           91.0
# 92  20.1  157.0  1011.400000         33.990000   8.1     WB010           92.0
# 93   9.2  165.0  1011.400000         45.350000   1.3     WB011           93.0
# 94  14.2  179.0  1011.200000         57.600000   4.4     WB012           94.0
# 95   8.0  156.0  1010.100000         47.890000   5.0     WB013           95.0
#
#           StationName  Temperature  WindDirection  WindSpeed
# 0           Gollapudi         31.9            0.0       0.60
# 1            Tirumala         28.4            0.0       1.00
# 2        Bamunimaidan         24.0            0.0       0.53
# 3             Danapur         25.0            0.0       0.06
# 4            Shivpuri         25.0            0.0       0.08
# ..                ...          ...            ...        ...
# 91  Victoria Memorial         27.0            0.0       0.74
# 92         Ballygunge         27.0            0.0       1.64
# 93           Jadavpur         27.0            0.0       0.12
# 94        Barrackpore         27.0            0.0       0.19
# 95             Howrah         27.0            0.0       0.39
#
# [96 rows x 17 columns]

# %%
df_history[df_history["StationId"] == "AP001"].sort_values("Datetime")
# Out:
#           AQI   CO        City                    Datetime  DewPoint  NO2  \
# 0  105.792849  3.8  Vijayawada  2025-11-24 17:47:55.098270      22.0  9.6
#
#      O3  PM2.5  Pressure  RelativeHumidity  SO2 StationId  StationId_enc  \
# 0  16.9   94.0     759.0              62.0  2.3     AP001            0.0
#
#   StationName  Temperature  WindDirection  WindSpeed
# 0   Gollapudi         31.9            0.0        0.6

# %%
forecast = pd.read_csv(f"forecast/forecast_24h_{"AP001"}.csv")
forecast
# Out:
#                       Datetime         AQI
# 0   2025-11-24 18:47:55.150119  232.240996
# 1   2025-11-24 19:47:55.150119  232.763339
# 2   2025-11-24 20:47:55.150119  232.054257
# 3   2025-11-24 21:47:55.150119  232.092426
# 4   2025-11-24 22:47:55.150119  231.927521
# 5   2025-11-24 23:47:55.150119  231.616093
# 6   2025-11-25 00:47:55.150119  229.182870
# 7   2025-11-25 01:47:55.150119  227.727460
# 8   2025-11-25 02:47:55.150119  226.465517
# 9   2025-11-25 03:47:55.150119  226.324578
# 10  2025-11-25 04:47:55.150119  227.052139
# 11  2025-11-25 05:47:55.150119  227.337312
# 12  2025-11-25 06:47:55.150119  226.534567
# 13  2025-11-25 07:47:55.150119  224.183335
# 14  2025-11-25 08:47:55.150119  224.988067
# 15  2025-11-25 09:47:55.150119  223.374970
# 16  2025-11-25 10:47:55.150119  224.331393
# 17  2025-11-25 11:47:55.150119  225.595671
# 18  2025-11-25 12:47:55.150119  225.595671
# 19  2025-11-25 13:47:55.150119  227.004695
# 20  2025-11-25 14:47:55.150119  228.486184
# 21  2025-11-25 15:47:55.150119  229.867549
# 22  2025-11-25 16:47:55.150119  230.181970
# 23  2025-11-25 17:47:55.150119  231.384780

# %%
import pandas as pd
import matplotlib.pyplot as plt

station_id = "AP001"

forecast = pd.read_csv(f"forecast/forecast_24h_{station_id}.csv")
forecast["Datetime"] = pd.to_datetime(forecast["Datetime"])

plt.figure(figsize=(12,5))
plt.plot(forecast["Datetime"], forecast["AQI"])
plt.title(f"24-Hour AQI Forecast for {station_id}")
plt.xlabel("Datetime")
plt.ylabel("AQI")
plt.grid(True)
plt.show()
